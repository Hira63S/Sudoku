# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
from IPython.display import Image

Image(filename='white_img.png')

# %%
import cv2
filename = 'white_img.png'
W = 1000

# %%
img = cv2.imread(filename)

# %%
heigh, width, depth = img.shape

# %%
imgScale = W/width

# %%
newX, newY = img.shape[1]*imgScale, img.shape[0]*imgScale

# %%
new_img = cv2.resize(img, (int(newX), int(newY)))

# %%
cv2.imshow("Show by CV2", new_img)
cv2.waitKey(0)
cv2.imwrite('resize_white_img.png', new_img)
# Out:
# True

# %%
plt.imshow(new_img)

# %%
rows = [(30,130), (130,220), (235,325), (340,430), (455,545), (570,660), (660,750), (770,860), (890,970)]
columns = [(30,120), (140,220), (250,330), (355,445), (455,535), (565,655), (660,750), (760,870),(890,970)]

# %%
for unit in rows:
    for units in columns:
        print(unit, units)
# Out:
# (30, 130) (30, 120)
# (30, 130) (140, 220)
# (30, 130) (250, 330)
# (30, 130) (355, 445)
# (30, 130) (455, 535)
# (30, 130) (565, 655)
# (30, 130) (660, 750)
# (30, 130) (760, 870)
# (30, 130) (890, 970)
# (130, 220) (30, 120)
# (130, 220) (140, 220)
# (130, 220) (250, 330)
# (130, 220) (355, 445)
# (130, 220) (455, 535)
# (130, 220) (565, 655)
# (130, 220) (660, 750)
# (130, 220) (760, 870)
# (130, 220) (890, 970)
# (235, 325) (30, 120)
# (235, 325) (140, 220)
# (235, 325) (250, 330)
# (235, 325) (355, 445)
# (235, 325) (455, 535)
# (235, 325) (565, 655)
# (235, 325) (660, 750)
# (235, 325) (760, 870)
# (235, 325) (890, 970)
# (340, 430) (30, 120)
# (340, 430) (140, 220)
# (340, 430) (250, 330)
# (340, 430) (355, 445)
# (340, 430) (455, 535)
# (340, 430) (565, 655)
# (340, 430) (660, 750)
# (340, 430) (760, 870)
# (340, 430) (890, 970)
# (455, 545) (30, 120)
# (455, 545) (140, 220)
# (455, 545) (250, 330)
# (455, 545) (355, 445)
# (455, 545) (455, 535)
# (455, 545) (565, 655)
# ...

# %%
each_square = []
for unit in rows:
    for units in columns:
        each_square.append(new_img[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(new_img)

# %%
plt.imshow(each_square[80])

# %%
# column # 1 is good
# column # 2 is good
# column # 3 is good
# column # 4 is good
# column # 5 is good
# column # 6 is good
# column # 7 is good
# column # 8 is good
# column # 9 is good

# row # 1 is good
# row # 2 is good
# row # 3 is good
# row # 4 is good
# row # 5 is good
# row # 6 is good
# row # 7 is good
# row # 8 is good
# row # 9 is good

# %%
filename = 'white_img2.png'
W = 1000

# %%
img2 = cv2.imread(filename)
heigh, width, depth = img2.shape
img2Scale = W/width
newX, newY = img2.shape[1]*img2Scale, img2.shape[0]*img2Scale
new_img2 = cv2.resize(img2, (int(newX), int(newY)))
cv2.imshow("Show by CV2", new_img2)
cv2.waitKey(0)
cv2.imwrite('resize_white_img.png', new_img2)
# Out:
# True

# %%
plt.imshow(new_img2)

# %%
rows = [(5,115), (125,215), (235,325), (340,430), (455,545), (570,660), (680,770), (785,875), (890,980)]
columns = [(30,120), (130,220), (240,330), (355,445), (455,545), (565,655), (660,770), (800,890),(890,980)]

# %%
rows = [(15,115), (125,225), (235,335), (340,440), (455,555), (570,670), (680,780), (785,885), (890,990)]
columns = [(30,130), (130,230), (240,340), (355,455), (455,555), (565,665), (670,770), (800,900),(890,990)]

# %%
for unit in rows:
    for units in columns:
        print(unit, units)
# Out:
# (15, 115) (30, 130)
# (15, 115) (130, 230)
# (15, 115) (240, 340)
# (15, 115) (355, 455)
# (15, 115) (455, 555)
# (15, 115) (565, 665)
# (15, 115) (670, 770)
# (15, 115) (800, 900)
# (15, 115) (890, 990)
# (125, 225) (30, 130)
# (125, 225) (130, 230)
# (125, 225) (240, 340)
# (125, 225) (355, 455)
# (125, 225) (455, 555)
# (125, 225) (565, 665)
# (125, 225) (670, 770)
# (125, 225) (800, 900)
# (125, 225) (890, 990)
# (235, 335) (30, 130)
# (235, 335) (130, 230)
# (235, 335) (240, 340)
# (235, 335) (355, 455)
# (235, 335) (455, 555)
# (235, 335) (565, 665)
# (235, 335) (670, 770)
# (235, 335) (800, 900)
# (235, 335) (890, 990)
# (340, 440) (30, 130)
# (340, 440) (130, 230)
# (340, 440) (240, 340)
# (340, 440) (355, 455)
# (340, 440) (455, 555)
# (340, 440) (565, 665)
# (340, 440) (670, 770)
# (340, 440) (800, 900)
# (340, 440) (890, 990)
# (455, 555) (30, 130)
# (455, 555) (130, 230)
# (455, 555) (240, 340)
# (455, 555) (355, 455)
# (455, 555) (455, 555)
# (455, 555) (565, 665)
# ...

# %%
each_square2 = []
for unit in rows:
    for units in columns:
        each_square2.append(new_img2[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(new_img2)

# %%
plt.imshow(each_square2[0])

# %%
for img in each_square2:
    print(img.shape)
# Out:
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# ...

# %%
each_square2[11].shape
# Out:
# (90, 80, 3)

# %%
filename = 'white_img.png'
img = cv2.imread(filename)
def crop(image):
    image = cv2.imread(filename)
    W = 1000
    heigh, width, depth = image.shape
    imgScale = W/width
    newX, newY = image.shape[1]*imgScale, image.shape[0]*imgScale
    new_img = cv2.resize(image, (int(newX), int(newY)))
    cv2.imshow("Show by CV2", new_img)
    cv2.waitKey(0)
    cv2.imwrite('resize_white_img.png', new_img)
    plt.imshow(new_img)

# %%
filename = 'white_img3.png'
img3 = cv2.imread(filename)

# %%
plt.imshow(img3)

# %%
W = 1000
heigh, width, depth = img3.shape
imgScale = W/width
newX, newY = img3.shape[1]*imgScale, img3.shape[0]*imgScale
new_img3 = cv2.resize(img3, (int(newX), int(newY)))
cv2.imshow("Show by CV2", new_img3)
cv2.waitKey(0)
cv2.imwrite('resize_white_img.png', new_img3)
plt.imshow(new_img3)

# %%
rows = [(15,115), (125,225), (235,335), (340,440), (455,555), (570,670), (680,780), (775,875), (890,990)]
columns = [(30,130), (130,230), (240,340), (355,455), (455,555), (565,665), (670,770), (800,900),(890,990)]

# %%
for unit in rows:
    for units in columns:
        print(unit, units)
# Out:
# (15, 115) (30, 130)
# (15, 115) (130, 230)
# (15, 115) (240, 340)
# (15, 115) (355, 455)
# (15, 115) (455, 555)
# (15, 115) (565, 665)
# (15, 115) (670, 770)
# (15, 115) (800, 900)
# (15, 115) (890, 990)
# (125, 225) (30, 130)
# (125, 225) (130, 230)
# (125, 225) (240, 340)
# (125, 225) (355, 455)
# (125, 225) (455, 555)
# (125, 225) (565, 665)
# (125, 225) (670, 770)
# (125, 225) (800, 900)
# (125, 225) (890, 990)
# (235, 335) (30, 130)
# (235, 335) (130, 230)
# (235, 335) (240, 340)
# (235, 335) (355, 455)
# (235, 335) (455, 555)
# (235, 335) (565, 665)
# (235, 335) (670, 770)
# (235, 335) (800, 900)
# (235, 335) (890, 990)
# (340, 440) (30, 130)
# (340, 440) (130, 230)
# (340, 440) (240, 340)
# (340, 440) (355, 455)
# (340, 440) (455, 555)
# (340, 440) (565, 665)
# (340, 440) (670, 770)
# (340, 440) (800, 900)
# (340, 440) (890, 990)
# (455, 555) (30, 130)
# (455, 555) (130, 230)
# (455, 555) (240, 340)
# (455, 555) (355, 455)
# (455, 555) (455, 555)
# (455, 555) (565, 665)
# ...

# %%
each_square3 = []
for unit in rows:
    for units in columns:
        each_square3.append(new_img3[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(new_img3)

# %%
plt.imshow(each_square3[69])

# %%
filename = 'white_img.png'
img = cv2.imread(filename)
def crop(image):
    image = cv2.imread(filename)
    W = 1000
    heigh, width, depth = image.shape
    imgScale = W/width
    newX, newY = image.shape[1]*imgScale, image.shape[0]*imgScale
    new_img = cv2.resize(image, (int(newX), int(newY)))
    cv2.imshow("Show by CV2", new_img)
    cv2.waitKey(0)
    cv2.imwrite('resize_white_img.png', new_img)
    plt.imshow(new_img)

# %%
filename = 'white_img4.png'
img4 = cv2.imread(filename)

# %%
W = 1000
heigh, width, depth = img4.shape
imgScale = W/width
newX, newY = img4.shape[1]*imgScale, img4.shape[0]*imgScale
new_img4 = cv2.resize(img4, (int(newX), int(newY)))
cv2.imshow("Show by CV2", new_img4)
cv2.waitKey(0)
cv2.imwrite('resize_white_img.png', new_img4)
plt.imshow(new_img4)

# %%
rows = [(15,115), (125,225), (235,335), (340,440), (455,555), (570,670), (680,780), (775,875), (890,990)]
columns = [(30,130), (130,230), (240,340), (355,455), (455,555), (565,665), (670,770), (800,900),(890,990)]

# %%
for unit in rows:
    for units in columns:
        print(unit, units)
# Out:
# (15, 115) (30, 130)
# (15, 115) (130, 230)
# (15, 115) (240, 340)
# (15, 115) (355, 455)
# (15, 115) (455, 555)
# (15, 115) (565, 665)
# (15, 115) (670, 770)
# (15, 115) (800, 900)
# (15, 115) (890, 990)
# (125, 225) (30, 130)
# (125, 225) (130, 230)
# (125, 225) (240, 340)
# (125, 225) (355, 455)
# (125, 225) (455, 555)
# (125, 225) (565, 665)
# (125, 225) (670, 770)
# (125, 225) (800, 900)
# (125, 225) (890, 990)
# (235, 335) (30, 130)
# (235, 335) (130, 230)
# (235, 335) (240, 340)
# (235, 335) (355, 455)
# (235, 335) (455, 555)
# (235, 335) (565, 665)
# (235, 335) (670, 770)
# (235, 335) (800, 900)
# (235, 335) (890, 990)
# (340, 440) (30, 130)
# (340, 440) (130, 230)
# (340, 440) (240, 340)
# (340, 440) (355, 455)
# (340, 440) (455, 555)
# (340, 440) (565, 665)
# (340, 440) (670, 770)
# (340, 440) (800, 900)
# (340, 440) (890, 990)
# (455, 555) (30, 130)
# (455, 555) (130, 230)
# (455, 555) (240, 340)
# (455, 555) (355, 455)
# (455, 555) (455, 555)
# (455, 555) (565, 665)
# ...

# %%
each_square4 = []
for unit in rows:
    for units in columns:
        each_square4.append(new_img4[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(new_img4)

# %%
plt.imshow(each_square4[47])

# %%
import random

# %%
for img in each_square:
    n = 80
    plt.imshow(each_square[n])

# %%
for img in each_square4:
    print(img.shape)
# Out:
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# ...
