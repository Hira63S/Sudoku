# %% [markdown]
# # Image Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image
import cv2
import os
from torchvision import transforms
import torch
import pickle
from random import shuffle

# %%
(Image(filename='images/white_img3.png'))

# %% [markdown]
# ## Read in the image:

# %%
filename = 'images/white_img3.png'
img = cv2.imread(filename)

# %%
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
W = 1000
heigh, width, depth = img.shape
imgScale = W/width
newX, newY = img.shape[1]*imgScale, img.shape[0]*imgScale
new_img = cv2.resize(img, (int(newX), int(newY)))
cv2.imshow("Show by CV2", new_img)
cv2.waitKey(0)
# cv2.imwrite('resize_white_img.png', new_img)
plt.imshow(new_img)

# %%
invert_img = cv2.bitwise_not(img)
cv2.imshow("invert1", invert_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rows = [(15,125), (125,225), (235,335), (340,440), (455,555), (570,670), (680,780), (775,875), (890,990)]
columns = [(30,130), (130,230), (240,340), (355,455), (455,555), (565,665), (670,770), (800,900),(890,990)]

# %%
images_list = []
for unit in rows:
    for units in columns:
        images_list.append(invert_img[unit[0]:unit[1], units[0]:units[1]])

# %%
images_list = []
for unit in rows:
    for units in columns:
        images_list.append(invert_img[unit[0]:unit[1], units[0]:units[1]])

# %%
plt.imshow(images_list[52])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-ffff5b71bf6c> in <module>
# ----> 1 plt.imshow(images_list[52])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
# ...

# %% [markdown]
# ### To save the inverted and preprocessed images to local folder:

# %%
# for i in range(len(images_list)):
#    if i <= 9:
#        cv2.imwrite("0"+f"{i}_flip.png", images_list[i])
#    else:
#        cv2.imwrite(f"{i}_flip.png", images_list[i])

# %%
# for i in range(len(images_list)):
#    cv2.imwrite(f"0{i}_flip.png", images_list[i])

# cv2.imwrite("flip_img81.png", images_list[80])

# %%
# To pull in the images from the local folder, and prepare them to be passed onto the model:

# %%
def final(images_list):
    final_images = []
    for i in range(len(images_list)):
        img_array = cv2.imread(os.path.join(IMG_DIR, images))
        img_array = cv2.cvtColor(images_list[i], cv2.COLOR_BGR2GRAY)
        resize_img = cv2.resize(img_array, (28,28))
        final_images.append(resize_img)

# %%
final(images_list)

# %%
plt.imshow(final_images[52]) # 47, 57, 69,

# %%
type(final_images[52])
# Out:
# numpy.ndarray

# %%
final_images[0][0].dtype
# Out:
# dtype('uint8')

# %%
final_images[2] = final_images[2].astype(float)

# %%
transform = transforms.ToTensor()

# %% [markdown]
# ## How to save?

# %%
tensor1 =transform(dfexp['allimages'][200][0])

# %%
for i in range(len(final_images)):
    if final_images[i].max() != 255:
        np.full_like(final_images[i], 0)

# %%
plt.imshow(np.full_like(final_images[5], 0))

# %%
plt.imshow(final_images[1])

# %% [markdown]
# # Creating tuples

# %%
plt.imshow(new_img)

# %%
final_images[7].min(), final_images[7].max()
# Out:
# (0, 31)

# %%
copy_img1_1 = [(np.copy([final_images[52]]), 1) for i in range(20)] # values is the image
copy_img1_2 = [(np.copy([final_images[76]]), 1) for i in range(20)]
#copy_img1_3 = [(np.copy(final_images[60]), 1) for i in range(20)]
#copy_img1_4 = [(np.copy(final_images[66]), 1) for i in range(20)]

# %%
plt.imshow(final_images[1], cmap='gray')

# %%
copy_img1_1.extend(copy_img1_2)
len(copy_img1_1)
# Out:
# 40

# %%
copy_img1_1[0][1]
# Out:
# 1

# %%
copy_img2_1 = [(np.copy([final_images[17]]), 2) for i in range(20)]
copy_img2_2 = [(np.copy([final_images[37]]), 2) for i in range(20)]
copy_img2_3 = [(np.copy([final_images[66]]), 2) for i in range(20)]
copy_img2_4 = [(np.copy([final_images[60]]), 2) for i in range(20)]
#copy_img2_5 = [(np.copy(final_images[60]), 2) for i in range(20)]
#copy_img2_6 = [(np.copy(final_images[66]), 2) for i in range(20)]

# %%
copy_img2_1.extend(copy_img2_2)
copy_img2_1.extend(copy_img2_3)
copy_img2_1.extend(copy_img2_4)

# %%
len(copy_img2_1)
# Out:
# 80

# %%
copy_img3_1 = [(np.copy([final_images[3]]), 3) for i in range(20)]
copy_img3_2 = [(np.copy([final_images[68]]), 3) for i in range(20)]
copy_img3_3 = [(np.copy([final_images[43]]), 3) for i in range(20)]
copy_img3_4 = [(np.copy([final_images[50]]), 3) for i in range(20)]
#copy_img3_5 = [(np.copy(final_images[60]), 3) for i in range(20)]
#copy_img3_6 = [(np.copy(final_images[66]), 3) for i in range(20)]

# %%
copy_img3_1.extend(copy_img3_2)
copy_img3_1.extend(copy_img3_3)
copy_img3_1.extend(copy_img3_4)
len(copy_img3_1)
# Out:
# 80

# %%
copy_img4_1 = [(np.copy([final_images[11]]), 4) for i in range(20)]
copy_img4_2 = [(np.copy([final_images[40]]), 4) for i in range(20)]
copy_img4_3 = [(np.copy([final_images[63]]), 4) for i in range(20)]
#copy_img4_4 = [(np.copy(final_images[37]), 4) for i in range(20)]
#copy_img4_5 = [(np.copy(final_images[60]), 4) for i in range(20)]
#copy_img4_6 = [(np.copy(final_images[66]), 4) for i in range(20)]

# %%
copy_img4_1.extend(copy_img4_2)
copy_img4_1.extend(copy_img4_3)
#copy_img4_1.extend(copy_img4_4)
len(copy_img4_1)
# Out:
# 60

# %%
copy_img5_1 = [(np.copy([final_images[10]]), 5) for i in range(20)]
copy_img5_2 = [(np.copy([final_images[23]]), 5) for i in range(20)]
copy_img5_3 = [(np.copy([final_images[80]]), 5) for i in range(20)]
#copy_img5_4 = [(np.copy(final_images[37]), 5) for i in range(20)]
#copy_img5_5 = [(np.copy(final_images[60]), 5) for i in range(20)]
#copy_img5_6 = [(np.copy(final_images[66]), 5) for i in range(20)]

# %%
copy_img5_1.extend(copy_img5_2)
copy_img5_1.extend(copy_img5_3)
len(copy_img5_1)
# Out:
# 60

# %%
copy_img6_1 = [(np.copy([final_images[20]]), 6) for i in range(20)]
copy_img6_2 = [(np.copy([final_images[68]]), 6) for i in range(20)]
copy_img6_3 = [(np.copy([final_images[77]]), 6) for i in range(20)]
copy_img6_4 = [(np.copy([final_images[70]]), 6) for i in range(20)]
#copy_img6_5 = [(np.copy(final_images[60]), 6) for i in range(20)]
#copy_img6_6 = [(np.copy(final_images[66]), 6) for i in range(20)]

# %%
copy_img6_1.extend(copy_img6_2)
copy_img6_1.extend(copy_img6_3)
copy_img6_1.extend(copy_img6_4)

# %%
copy_img7_1 = [(np.copy([final_images[0]]), 7) for i in range(20)]
copy_img7_2 = [(np.copy([final_images[12]]), 7) for i in range(20)]
copy_img7_3 = [(np.copy([final_images[33]]), 7) for i in range(20)]
copy_img7_4 = [(np.copy([final_images[31]]), 7) for i in range(20)]
copy_img7_5 = [(np.copy([final_images[47]]), 7) for i in range(20)]
copy_img7_6 = [(np.copy([final_images[57]]), 7) for i in range(20)]
copy_img7_7 = [(np.copy([final_images[69]]), 7) for i in range(20)]

# %%
copy_img7_1.extend(copy_img7_2)
copy_img7_1.extend(copy_img7_3)
copy_img7_1.extend(copy_img7_4)
copy_img7_1.extend(copy_img7_5)
copy_img7_1.extend(copy_img7_6)
copy_img7_1.extend(copy_img7_7)
len(copy_img7_1)
# Out:
# 140

# %%
copy_img8_1 = [(np.copy([final_images[2]]), 8) for i in range(20)]
copy_img8_2 = [(np.copy([final_images[12]]), 8) for i in range(20)]
copy_img8_3 = [(np.copy([final_images[33]]), 8) for i in range(20)]
copy_img8_4 = [(np.copy([final_images[55]]), 8) for i in range(20)]
#copy_img8_5 = [(np.copy(final_images[60]), 8) for i in range(20)]
#copy_img8_6 = [(np.copy(final_images[66]), 8) for i in range(20)]

# %%
copy_img8_1.extend(copy_img8_2)
copy_img8_1.extend(copy_img8_3)
copy_img8_1.extend(copy_img8_4)
len(copy_img8_1)
# Out:
# 80

# %%
copy_img1_1[0][0].shape
# Out:
# (1, 28, 28)

# %%
len(dict_exp['allimages'])
# Out:
# 620

# %%
#copy_img9_1 = [(np.copy(final_images[37]), 9) for i in range(20)]
#copy_img9_2 = [(np.copy(final_images[60]), 9) for i in range(20)]
#copy_img9_3 = [(np.copy(final_images[66]), 9) for i in range(20)]
#copy_img9_4 = [(np.copy(final_images[37]), 9) for i in range(20)]
#copy_img9_5 = [(np.copy(final_images[60]), 9) for i in range(20)]
#copy_img9_6 = [(np.copy(final_images[66]), 9) for i in range(20)]

# %%
copy_img1_1.extend(copy_img2_1)
copy_img1_1.extend(copy_img3_1)
copy_img1_1.extend(copy_img4_1)
copy_img1_1.extend(copy_img5_1)
copy_img1_1.extend(copy_img6_1)
copy_img1_1.extend(copy_img7_1)
copy_img1_1.extend(copy_img8_1)

# %%
len(copy_img1_1)
# Out:
# 620

# %%
type(copy_img1_1[i][0])
# Out:
# numpy.ndarray

# %%
shuffle(copy_img1_1)

# %%
transform = transforms.ToTensor()

# %% [markdown]
# for num in copy_img1_1:
#     print(type(num))

# %%
for i, b in num

# %%
tensors[30][0].view(1,1,28,28).shape
# Out:
# torch.Size([1, 1, 28, 28])

# %%
type(tensors[30][1])
# Out:
# int

# %%
tensors = []
for num in copy_img1_1:
    tensors.append((transform(num[0]).view(1,1,28,28), num[1]))
        
#    for i, b in num: #num represents the tuple itself
#        i = transform(i)
#        tensors.append((i,b))
#        transform(copy_img1_1[i][b])

# %%
tensors[20][0].shape
# Out:
# torch.Size([1, 1, 28, 28])

# %%
train_loader = (n for n in tensors)

# %%
type(train_loader)
# Out:
# generator

# %%
train_loader
# Out:
# <generator object <genexpr> at 0x00000240ECB50B88>

# %%
import helper

# %%
images, labels = next(iter(train_loader))

# %%
images, label = next(iter(train_loader))
helper.imshow(images[0,:]);

# %%
train_loader = torch.utils.data.DataLoader(tensors, batch_size=64, shuffle=True)

# %%
# images, labels = next(iter(train_loader))

# %%
# labels

# %%
# images[0,:]

# %% [markdown]
# # Models

# %% [markdown]
# We will be creating a CNN to train our model.

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(5*5*16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 5*5*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
torch.manual_seed(42)
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003)

epochs = 25
for e in range(epochs):
    running_loss = 0
    for images, labels in train_loader:
        # Flatten MNIST images into a 784 long vector
        images = images.view(images.shape[0], -1)
    
        # TODO: Training pass
        optimizer.zero_grad()
        
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print(f"Training loss: {running_loss/len(train_loader)}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-597-6e273ada0729> in <module>
#      13         optimizer.zero_grad()
#      14
# ---> 15         output = model(images)
#      16         loss = criterion(output, labels)
#      17         loss.backward()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-595-19d49927f4f0> in forward(self, X)
#       9
#      10     def forward(self, X):
# ---> 11         X = F.relu(self.conv1(X))
#      12         X = F.max_pool2d(X, 2, 2)
#      13         X = F.relu(self.conv2(X))
#
# ...

# %%
def convert(tensor): # always be passing in an array
    grid = []
    for i in range(len(tensor)):
        if tensor[i].mean().item() <= 22:
            grid.append(".")
        else:
            grid.append(str(model(tensor[i].view(1,1,28,28)).argmax().item()))
    return grid

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(5*5*16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 5*5*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
torch.manual_seed(42)
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(5*5*16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 5*5*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
import time
start_time = time.time()

epochs = 5
train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        b+=1
        
        # Apply the model
        y_pred = model(X_train)  # we don't flatten X-train here
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print interim results
#        if b%600 == 0:
#            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/60000]  loss: {loss.item():10.8f}  \
#accuracy: {trn_corr.item()*100/(10*b):7.3f}%')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-578-5fbb2e54b4fe> in <module>
#      17
#      18         # Apply the model
# ---> 19         y_pred = model(X_train)  # we don't flatten X-train here
#      20         loss = criterion(y_pred, y_train)
#      21
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-574-19d49927f4f0> in forward(self, X)
#       9
#      10     def forward(self, X):
# ---> 11         X = F.relu(self.conv1(X))
#      12         X = F.max_pool2d(X, 2, 2)
#      13         X = F.relu(self.conv2(X))
#
# ...
